# %%
# Importing the pandas library with the alias pd
import pandas as pd

# %% [markdown]
# # Data Preparation

# %%
# Load the dataset into a DataFrame
df = pd.read_csv('dataset.csv')

# %%
# Display the DataFrame 'df'
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
# Remove the 'salary' and 'salary_currency' columns from the DataFram
df.drop(columns=['salary','salary_currency'])
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
# Remove the 'salary' and 'salary_currency' columns from the DataFram
df.drop(columns=['salary','salary_currency'], inplace=True)

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
# Check for missing values in the DataFrame 'df'
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Remove rows with missing values from the DataFrame
df.dropna(inplace=True)

# %%
# Display the DataFrame to inspect the cleaned data
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
# Display duplicate rows in the DataFrame and keep only the first occurrence
df[df.duplicated()]
# Out:
#       work_year experience_level employment_type           job_title  \
# 115        2023               SE              FT      Data Scientist
# 123        2023               SE              FT  Analytics Engineer
# 153        2023               MI              FT       Data Engineer
# 154        2023               MI              FT       Data Engineer
# 160        2023               SE              FT       Data Engineer
# ...         ...              ...             ...                 ...
# 3439       2022               MI              FT      Data Scientist
# 3440       2022               SE              FT       Data Engineer
# 3441       2022               SE              FT       Data Engineer
# 3586       2021               MI              FT       Data Engineer
# 3709       2021               MI              FT      Data Scientist
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %%
# Iterate over each column in the DataFrame
for column in df.columns:
    # Get the unique values in the current column
    unique_values = df[column].unique()
    
    # Print the column name and its unique values
    print(f"{column}: {unique_values}")
    print()
# Out:
# work_year: [2023 2022 2020 2021]
#
# experience_level: ['SE' 'MI' 'EN' 'EX']
#
# employment_type: ['FT' 'CT' 'FL' 'PT']
#
# job_title: ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
# ...

# %%
# Replace values in the 'experience_level' column with more descriptive labels
df['experience_level'].replace({'SE':'Senior Level/Expert',
                              'MI':'Medium Level/Intermediate',
                               'EN':'Entry Level',
                               'EX':'Executive Level'}, inplace=True)

# %%
# Filter the DataFrame to display rows where the 'experience_level' column is 'Senior Level/Expert'
df[df['experience_level'] == 'Senior Level/Expert']
# Out:
#       work_year     experience_level employment_type  \
# 0          2023  Senior Level/Expert              FT
# 3          2023  Senior Level/Expert              FT
# 4          2023  Senior Level/Expert              FT
# 5          2023  Senior Level/Expert              FT
# 6          2023  Senior Level/Expert              FT
# ...         ...                  ...             ...
# 3744       2020  Senior Level/Expert              FT
# 3745       2021  Senior Level/Expert              FT
# 3749       2021  Senior Level/Expert              FT
# 3750       2020  Senior Level/Expert              FT
# 3754       2021  Senior Level/Expert              FT
#
#                       job_title  salary_in_usd employee_residence  \
# 0      Principal Data Scientist          85847                 ES
# 3                Data Scientist         175000                 CA
# 4                Data Scientist         120000                 CA
# ...

# %%
# Filter the DataFrame to display rows where the 'experience_level' column is 'Medium Level/Intermediate'
df[df['experience_level'] == 'Medium Level/Intermediate']
# Out:
#       work_year           experience_level employment_type  \
# 1          2023  Medium Level/Intermediate              CT
# 2          2023  Medium Level/Intermediate              CT
# 19         2023  Medium Level/Intermediate              FT
# 20         2023  Medium Level/Intermediate              FT
# 35         2023  Medium Level/Intermediate              FT
# ...         ...                        ...             ...
# 3743       2020  Medium Level/Intermediate              FT
# 3746       2021  Medium Level/Intermediate              FT
# 3747       2021  Medium Level/Intermediate              FT
# 3748       2021  Medium Level/Intermediate              FT
# 3751       2021  Medium Level/Intermediate              FT
#
#                                job_title  salary_in_usd employee_residence  \
# 1                            ML Engineer          30000                 US
# 2                            ML Engineer          25500                 US
# ...

# %%
# Filter the DataFrame to display rows where the 'experience_level' column is 'Entry Level'
df[df['experience_level'] == 'Entry Level']
# Out:
#       work_year experience_level employment_type                job_title  \
# 13         2023      Entry Level              FT        Applied Scientist
# 14         2023      Entry Level              FT        Applied Scientist
# 39         2023      Entry Level              FT     Data Quality Analyst
# 40         2023      Entry Level              FT  Compliance Data Analyst
# 42         2023      Entry Level              FT        Applied Scientist
# ...         ...              ...             ...                      ...
# 3724       2021      Entry Level              FT    Business Data Analyst
# 3729       2021      Entry Level              FT             AI Scientist
# 3735       2021      Entry Level              PT             AI Scientist
# 3752       2020      Entry Level              FT           Data Scientist
# 3753       2020      Entry Level              CT    Business Data Analyst
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %%
# Filter the DataFrame to display rows where the 'experience_level' column is 'Executive Level'
df[df['experience_level'] == 'Executive Level']
# Out:
#       work_year experience_level employment_type                 job_title  \
# 58         2023  Executive Level              FT            Data Scientist
# 59         2023  Executive Level              FT            Data Scientist
# 183        2020  Executive Level              FT        Staff Data Analyst
# 203        2023  Executive Level              FT             Data Engineer
# 204        2023  Executive Level              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 3559       2020  Executive Level              FT             Data Engineer
# 3643       2021  Executive Level              FT  Director of Data Science
# 3660       2021  Executive Level              FT   Data Science Consultant
# 3675       2021  Executive Level              CT  Principal Data Scientist
# 3697       2020  Executive Level              FT  Director of Data Science
#
# ...

# %% [markdown]
# # Data Analysis

# %%
# Calculate the sum of values in the 'remote_ratio' column
final_sum = df['remote_ratio'].sum()
final_sum
# Out:
# 173750

# %%
# Calculate the mean (average) of values in the 'remote_ratio' column
final_mean = df['remote_ratio'].mean()
final_mean
# Out:
# 46.271637816245004

# %%
# Calculate the standard deviation of values in the 'remote_ratio' column
standard_deviation = df['remote_ratio'].std()
standard_deviation
# Out:
# 48.58905047058756

# %%
# Calculate the skewness of values in the 'remote_ratio' column
skewness = df['remote_ratio'].skew()
skewness
# Out:
# 0.1494539003820896

# %%
# Calculate the kurtosis of values in the 'remote_ratio' column
final_kurtosis = df['remote_ratio'].kurtosis()
final_kurtosis
# Out:
# -1.925036324549662

# %%
# Print summary statistics of sum, mean, standard deviation, skewness, and kurtosis of 'remote_ratio' column
print("Summary statistics of sum, mean, standard deviation, skewness, and kurtosis of 'remote_ratio' column")
print()
print('Sum: ', final_sum)
print('Mean: ', final_mean)
print('Standard Deviation: ', standard_deviation)
print('Skewness: ', skewness)
print('Kurtosis: ', final_kurtosis)
# Out:
# Summary statistics of sum, mean, standard deviation, skewness, and kurtosis of 'remote_ratio' column
#
# Sum:  173750
# Mean:  46.271637816245004
# Standard Deviation:  48.58905047058756
# Skewness:  0.1494539003820896
# Kurtosis:  -1.925036324549662

# %%
# Select only columns of type 'int64'
numerical_columns = df.select_dtypes(include='int64')

# Calculate the correlation matrix for the selected numerical columns
correlation = numerical_columns.corr()

# Display the correlation matrix
correlation
# Out:
#                work_year  salary_in_usd  remote_ratio
# work_year        1.00000       0.228290     -0.236430
# salary_in_usd    0.22829       1.000000     -0.064171
# remote_ratio    -0.23643      -0.064171      1.000000

# %% [markdown]
# # Data Exploration

# %%
# Import the matplotlib.pyplot module with the alias plt
import matplotlib.pyplot as plt

# %%
# Count the frequency of each job title and get the top 15 most common jobs
top_15_jobs = df['job_title'].value_counts().head(15)
top_15_jobs
# Out:
# job_title
# Data Engineer                 1040
# Data Scientist                 840
# Data Analyst                   612
# Machine Learning Engineer      289
# Analytics Engineer             103
# Data Architect                 101
# Research Scientist              82
# Data Science Manager            58
# Applied Scientist               58
# Research Engineer               37
# ML Engineer                     34
# Data Manager                    29
# Machine Learning Scientist      26
# Data Science Consultant         24
# Data Analytics Manager          22
# Name: count, dtype: int64

# %%
# Create a figure with a specific size
plt.figure(figsize=(10, 5))

# Create a bar plot to visualize the top 15 jobs
top_15_jobs.plot(kind='bar', color='purple')

# Set the title of the plot
plt.title('Top 15 Jobs')

# Set the label for the x-axis
plt.xlabel('Job Title')

# Set the label for the y-axis
plt.ylabel('Frequency')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
# Group the data by job title and calculate the mean salary for each group
average_salary_job = df.groupby('job_title')['salary_in_usd'].mean()

# Find the job title with the highest average salary
highest_salary_job = average_salary_job.idxmax()
highest_salary_job
# Out:
# 'Data Science Tech Lead'

# %%
# Create a figure with a specific size
plt.figure(figsize=(20, 20))

# Create a bar plot to visualize the average salary for each job title
average_salary_job.plot(kind='bar', color='purple')

# Set the title of the plot
plt.title('Average Salary by Job Title')

# Set the label for the x-axis
plt.xlabel('Job Title')

# Set the label for the y-axis
plt.ylabel('Average Salary (USD)')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
# Calculate the mean salary for each experience level by grouping the DataFrame by 'experience_level'
salary_by_experience = df.groupby('experience_level')['salary_in_usd'].mean()
salary_by_experience
# Out:
# experience_level
# Entry Level                   78546.284375
# Executive Level              194930.929825
# Medium Level/Intermediate    104525.939130
# Senior Level/Expert          153051.071542
# Name: salary_in_usd, dtype: float64

# %%
# Create a figure with a specific size
plt.figure(figsize=(10, 5))

# Group the data by experience level and calculate the mean salary for each group,then create a bar plot to 
#visualize the average salary for each experience level
salary_by_experience.plot(kind='bar', color='purple')

# Set the title of the plot
plt.title('Average Salary by Experience Level')

# Set the label for the x-axis
plt.xlabel('Experience Level')

# Set the label for the y-axis
plt.ylabel('Average Salary (USD)')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=30)

# Display the plot
plt.show()

# %%
# Create a figure with a specific size
plt.figure(figsize=(12, 8))

# Create the first subplot (1 row, 2 columns, position 1)
plt.subplot(1, 2, 1)

# Plot a histogram of the 'remote_ratio' column with 8 bins
plt.hist(df['salary_in_usd'], color='purple', bins=8)

# Set the title of the first subplot
plt.title('Histogram of Salary')

# Set the label for the x-axis of the first subplot
plt.xlabel('Salary')

# Set the label for the y-axis of the first subplot
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
# Create a figure with a specific size
plt.figure(figsize=(30, 1))

# Create the second subplot (1 row, 2 columns, position 2)
plt.subplot(1, 2, 2)

# Create a box plot of the 'salary_in_usd' column
plt.boxplot(df['salary_in_usd'], vert=False)

# Set the title of the second subplot
plt.title('Box plot of Salary')

# Set the label for the x-axis of the second subplot
plt.xlabel('Salary')

# Display the plot
plt.show()
